# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = np.random.randn(1000)
sns.histplot(data, kde=True) # Create a histogram with a kernel density estimate (KDE) overlay
plt.show() # Display the plot
